# %%
import matplotlib.pyplot as plt
import numpy as np
import uproot
import pandas as pd
import matplotlib.ticker as mticker
import math
#open root file


#df = uproot.open(
 #   "/volatile/clas12/cooperb/SULI/pid_training_test.root:PhysicsEvents"
#).arrays(library="pd")
cols = ["pid", "mc_matching_pid", "p", "theta", "beta", "chi2pid", "rich_RQ", "vz","phi"]
df = uproot.open("/volatile/clas12/cooperb/SULI/pid_training_v1.root:PhysicsEvents").arrays(cols, library="pd")
#creates a list of matching events (excludes events that failed matching)
matched = df[df["mc_matching_pid"] != -9999].copy()

parts = [321, 211, 2212]
colors= ["Green", "Blue", "Red"]
labels=["K+", "Pi+", "P"]

# %%
print("phi:  ", df["phi"].describe())
print("\nQuick eyeball:")
print(f"  theta range: [{df['theta'].min():.2f}, {df['theta'].max():.2f}]")
print(f"  phi range:   [{df['phi'].min():.2f}, {df['phi'].max():.2f}]")
# Out:
# phi:   count    2.724581e+06
# mean     1.825227e+02
# std      1.039382e+02
# min      6.460996e-05
# 25%      9.476833e+01
# 50%      1.800184e+02
# 75%      2.743506e+02
# max      3.599999e+02
# Name: phi, dtype: float64
#
# Quick eyeball:
#   theta range: [0.77, 68.82]
#   phi range:   [0.00, 360.00]

# %%
#beta
dfs=[]
for i in range(3):
    id=parts[i]
    pidCut = matched[matched["mc_matching_pid"]==id]
    dfs.append(pidCut)

fig, ax = plt.subplots()
for i, df in enumerate(dfs):
    ax.hist(
        df["p"],
        bins=30,
        range=(0, 7.5),
        histtype='step',
        color=colors[i],
        density=True,
        linewidth=2,
        label=labels[i]
    )
ax.set_xlim(0, 7.5)
ax.set_xlabel("Momentum (GeV/c)")
ax.set_ylabel("Density")
ax.legend()
fig.savefig("figures/pidMomentums.png", dpi=150)

plt.show()

# %%
#theta
dfs=[]
for i in range(3):
    id=parts[i]
    pidCut = matched[matched["mc_matching_pid"]==id]
    dfs.append(pidCut)

fig, ax = plt.subplots()
for i, df in enumerate(dfs):
    ax.hist(
        df["theta"],
        bins=30,
        range=(0, 45),
        histtype='step',
        color=colors[i],
        density=True,
        linewidth=2,
        label=labels[i]
    )
ax.set_xlim(0, 45)
ax.set_xlabel("Theta")
ax.set_ylabel("Density")
ax.legend()
fig.savefig("figures/pidThetas.png", dpi=150)

plt.show()

# %%
#vz
dfs=[]
for i in range(3):
    id=parts[i]
    pidCut = matched[matched["mc_matching_pid"]==id]
    dfs.append(pidCut)

fig, ax = plt.subplots()
for i, df in enumerate(dfs):
    ax.hist(
        df["vz"],
        bins=30,
        range=(0, 1.7),
        histtype='step',
        color=colors[i],
        density=True,
        linewidth=2,
        label=labels[i]
    )
ax.set_xlim(0, 1.7)
ax.set_xlabel("Vz")
ax.set_ylabel("Density")
ax.legend()
fig.savefig("figures/pidVzs.png", dpi=150)
plt.show()

# %%
dfs=[]
for i in range(3):
    id=parts[i]
    pidCut = matched[matched["mc_matching_pid"]==id]
    dfs.append(pidCut)

fig, ax = plt.subplots()
for i, df in enumerate(dfs):
    ax.hist(
        df["phi"],
        bins=30,
        range=(0, 360),
        histtype='step',
        color=colors[i],
        density=True,
        linewidth=2,
        label=labels[i]
    )
ax.set_xlim(0, 360)
ax.set_xlabel("phi")
ax.set_ylabel("Density")
ax.legend()
fig.savefig("figures/pidPhis.png", dpi=150)

plt.show()

# %%
dfs=[]
for i in range(3):
    id=parts[i]
    pidCut = matched[matched["mc_matching_pid"]==id]
    dfs.append(pidCut)

fig, ax = plt.subplots()
for i, df in enumerate(dfs):
    ax.hist(
        df["chi2pid"],
        bins=100,
        range=(-10, 10),
        histtype='step',
        color=colors[i],
        density=True,
        linewidth=2,
        label=labels[i]
    )
ax.set_xlim(-10, 10)
ax.set_xlabel("chi2pid")
ax.set_ylabel("Density")
ax.legend()
fig.savefig("figures/pidChi2Pids.png", dpi=150)
plt.show()

# %%
dfs=[]
for i in range(3):
    id=parts[i]
    pidCut = matched[matched["mc_matching_pid"]==id]
    dfs.append(pidCut)

fig, ax = plt.subplots()
for i, df in enumerate(dfs):
    ax.hist(
        df["beta"],
        bins=30,
        range=(0, 1.1),
        histtype='step',
        color=colors[i],
        density=True,
        linewidth=2,
        label=labels[i]
    )
ax.set_xlim(0, 1.1)
ax.set_xlabel("Beta")
ax.set_ylabel("Density")
ax.legend()
fig.savefig("figures/pidBetas.png", dpi=150)
plt.show()

# %%
dfs=[]
for i in range(3):
    id=parts[i]
    pidCut = matched[matched["mc_matching_pid"]==id]
    dfs.append(pidCut)

fig, ax = plt.subplots()
for i, df in enumerate(dfs):
    ax.hist(
        df["rich_RQ"],
        bins=30,
        range=(0, 1),
        histtype='step',
        color=colors[i],
        density=True,
        linewidth=2,
        label=labels[i]
    )
ax.set_xlim(0, 1)
ax.set_ylim(0, 5)
ax.set_xlabel("rich_RQ")
ax.set_ylabel("Density")
ax.legend()
fig.savefig("figures/pidRichrqs.png", dpi=150)
plt.show()
