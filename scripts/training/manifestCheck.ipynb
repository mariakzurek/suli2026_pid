# %%
import json
with open("/volatile/clas12/cooperb/SULI/dataset_v01/manifest.json") as f:
    m = json.load(f)
print(m["p_max"])            # the --p-max you passed
print(m["n_rows"])  # row counts per split
print(m["feature_list"])     # list of feature column names that went in
print(m["git_sha"])          # repo state at build time
# Out:
# 3.2
# {'train': 249219, 'val': 126260, 'test': 134753}
# ['ftof_energy_1B', 'ftof_time_1B', 'ftof_path_1B', 'beta']
# 2073105
